# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
sin(pi)
# Out:
# 1.2246467991473532e-16

# %%
pi
# Out:
# 3.141592653589793

# %%
plot([-2, 10, 3, 13, 5])

# %%
randn(10)
# Out:
# array([-0.92041952,  0.73548453,  0.77706063, -0.62194772,  0.31783434,
#         0.26839552, -0.50368006,  0.53594877,  0.81432093, -0.94336062])

# %%
plot(randn(100))

# %%
plot([-2, 1, 2.7, 3.3], [3, -5, 6, 0])

# %% [markdown]
# ## 變數

# %%
a = 3

# %%
a + 3
# Out:
# 6

# %%
a = 5

# %%
a + 5
# Out:
# 10

# %%
a
# Out:
# 5

# %%
a ** 2
# Out:
# 25

# %% [markdown]
# ## List

# %%
L = [3, 4, 5, 2, -3, 5]

# %%
plot(L)

# %%
L = [1, 2, 3, 4]

# %%
G = [2, 3, 4, 5]

# %%
L + G
# Out:
# [1, 2, 3, 4, 2, 3, 4, 5]

# %%
L - G
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-9d7050e65523> in <module>
# ----> 1 L - G
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
2 * L
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4]

# %% [markdown]
# ## String

# %%
print("Hello, World")
# Out:
# Hello, World

# %%
name = "Tom"
print(name)
# Out:
# Tom

# %%
name
# Out:
# 'Tom'

# %%
hello = ", What's up"
print(name + hello)
# Out:
# Tom, What's up

# %%
5 * name
# Out:
# 'TomTomTomTomTom'

# %%
message = '''就是
中間換行
像這樣
'''

# %%
print(message)
# Out:
# 就是
# 中間換行
# 像這樣

# %%
message
# Out:
# '就是\n中間換行\n像這樣\n'

# %% [markdown]
# ## Input

# %%
m = input("美金價格：")
# Out:
# 美金價格：120

# %%
m
# Out:
# '120'

# %%
float(m) * 30.5
# Out:
# 3660.0

# %%
m = input("美金價格：")
TWD = float(m) * 30.5
print("合台幣" + str(TWD) + "元")
# Out:
# 美金價格：128
# 合台幣3904.0元
